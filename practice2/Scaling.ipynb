# %%
# ! pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/10.0 MB 6.3 MB/s eta 0:00:02
#    ------- -------------------------------- 1.8/10.0 MB 4.8 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.6/10.0 MB 4.4 MB/s eta 0:00:02
#    ------------- -------------------------- 3.4/10.0 MB 4.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.2/10.0 MB 4.2 MB/s eta 0:00:02
#    -------------------- ------------------- 5.0/10.0 MB 4.1 MB/s eta 0:00:02
#    ------------------------ --------------- 6.0/10.0 MB 4.1 MB/s eta 0:00:01
#    --------------------------- ------------ 6.8/10.0 MB 4.1 MB/s eta 0:00:01
#    ------------------------------ --------- 7.6/10.0 MB 4.1 MB/s eta 0:00:01
#    --------------------------------- ------ 8.4/10.0 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------ --- 9.2/10.0 MB 4.0 MB/s eta 0:00:01
# ...

# %%
import seaborn as sns
import pandas as pd

# %%
df= pd.DataFrame({"Age":[20,25,30,35,40], "Salary":[20000,30000,40000,50000,60000]})

# %%
df
# Out:
#    Age  Salary
# 0   20   20000
# 1   25   30000
# 2   30   40000
# 3   35   50000
# 4   40   60000

# %%
df.describe()
# Out:
#              Age        Salary
# count   5.000000      5.000000
# mean   30.000000  40000.000000
# std     7.905694  15811.388301
# min    20.000000  20000.000000
# 25%    25.000000  30000.000000
# 50%    30.000000  40000.000000
# 75%    35.000000  50000.000000
# max    40.000000  60000.000000

# %%
X = np.array((df.Age)).reshape(5,1)
Y = np.array((df.Salary)).reshape(5,1)

# %%
from sklearn.model_selection import train_test_split


X_Train, X_Test, Y_Train, Y_Test=train_test_split(X,Y, test_size=0.2)

# %%
import numpy as np
X_Train=np.array((X_Train))
X_Test=np.array((X_Test))
Y_Train=np.array((Y_Train))
Y_Test=np.array((Y_Test))

# %%
X_Train.shape
# Out:
# (4,)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_Train_scaler= scaler.fit_transform(X_Train, y = None)
y_Train_scaler= scaler.fit_transform(Y_Train, y = None)
x_Test_scaler= scaler.transform(X_Test)
y_Test_scaler= scaler.transform(Y_Test)

# %%
print(x_Train_scaler.mean())
print(x_Train_scaler.std())
# Out:
# 0.0
# 1.0

# %%
from sklearn.preprocessing import MinMaxScaler
scalar = MinMaxScaler()
X_Train_Scaler = scalar.fit_transform(X_Train)
X_Test_Scaler = scalar.transform(X_Test)
Y_Train_Scaler = scalar.fit_transform(Y_Train)
Y_Train_Scaler = scalar.transform(Y_Test)

# %%
print(X_Train_Scaler.mean())
print(X_Train_Scaler.std())
# Out:
# 0.5625
# 0.369754986443726
