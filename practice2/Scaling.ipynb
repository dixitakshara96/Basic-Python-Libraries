# %%
# ! pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/10.0 MB 6.3 MB/s eta 0:00:02
#    ------- -------------------------------- 1.8/10.0 MB 4.8 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.6/10.0 MB 4.4 MB/s eta 0:00:02
#    ------------- -------------------------- 3.4/10.0 MB 4.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.2/10.0 MB 4.2 MB/s eta 0:00:02
#    -------------------- ------------------- 5.0/10.0 MB 4.1 MB/s eta 0:00:02
#    ------------------------ --------------- 6.0/10.0 MB 4.1 MB/s eta 0:00:01
#    --------------------------- ------------ 6.8/10.0 MB 4.1 MB/s eta 0:00:01
#    ------------------------------ --------- 7.6/10.0 MB 4.1 MB/s eta 0:00:01
#    --------------------------------- ------ 8.4/10.0 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------ --- 9.2/10.0 MB 4.0 MB/s eta 0:00:01
# ...

# %%
import seaborn as sns

# %%
tip= sns.load_dataset("tips")
