# %%
import pandas as pd
import  numpy as np

# %%
data={"name":["radha","mira","mohan","sohan","rohan","rina","sita"], "salary":[10000,20000,30000,10000,300000,50000,20000]}
df=pd.DataFrame(data)

# %%
df
# Out:
#     name  salary
# 0  radha   10000
# 1   mira   20000
# 2  mohan   30000
# 3  sohan   10000
# 4  rohan  300000
# 5   rina   50000
# 6   sita   20000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.boxplot(data=df,x="salary")
# Out:
# <Axes: xlabel='salary'>

# %%
iqr=df["salary"].quantile(0.75)-df["salary"].quantile(0.25)
lower_limit=df["salary"].quantile(0.25)-(1.5*iqr)
upper_limit=df["salary"].quantile(0.75)+(1.5*iqr)

# %%
df[(df["salary"]<lower_limit) | (df["salary"]>upper_limit)]
# Out:
#     name  salary
# 4  rohan  300000

# %%
z_score=(df.salary-df.salary.mean())/df.salary.std() if(df.salary.std()) != 0 else 0
