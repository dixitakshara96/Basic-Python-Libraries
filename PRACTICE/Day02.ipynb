# %% [markdown]
# * 29 August 2026

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.datasets import fetch_california_housing

housing = fetch_california_housing( as_frame = True )

df = housing.frame

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
X = df.drop("MedHouseVal" , axis = 1)

y = df["MedHouseVal"]

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(X, y, random_state = 42, train_size = 0.2)

# %%
X_train.shape
# Out:
# (4128, 8)

# %%
y_train.shape
# Out:
# (4128,)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression() 

model.fit( X_train , y_train)
# Out:
# LinearRegression()

# %%
y_predict = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error( y_test, y_predict)

from sklearn.metrics import mean_squared_error

mse = mean_squared_error( y_test, y_predict)

from sklearn.metrics import root_mean_squared_error

rmse = root_mean_squared_error( y_test, y_predict)

from sklearn.metrics import r2_score

r2 = r2_score( y_test, y_predict)

# %%
print("MAE: ", mae)
print("\nMSE: ", mse)
print("\nRMSE: ", rmse)
print("\nR2_Score: ", r2)
# Out:
# MAE:  0.529593955305816
#
# MSE:  0.521843536040241
#
# RMSE:  0.7223873864072109
#
# R2_Score:  0.6070270765036976

# %% [markdown]
# ## Conclusion
#
# ### 1. How model calculate the best fit line ?
# * process : it makes a line then calculate the residual and then Square it for each datapoint finally sum the all called Sum of Squares of Residual (SS).
# * then compare SS of every posibble line the line which has LEAST SUM of SQUARE is the best line which can fit on the dataset
#
# ### 2. RESIDUAL = Actual Value - Predicted Value
# * +ve means Underestimated
# * -ve means Overestimated
# * 0 means Exact prediction
#
# ### 3. What is metrics ?
# * it is like a Report Card Of our MODEL like how well it is performing
# * we have different metrics
# * Analogy : we have different subjects in which our performance is measured according to the marks we get in each . Similarly we have different metrics to measure the performance of out model
# * MAE
# * MSE
# * RMSE
# * R2 Score
#
# ### 4. Mean Absolute Error (MAE) : we take the absolute value of residual of each amd every datapoint and then find the average of it.
# * This value simply means that our prediction is differ by X from the actual value
#
# ### 5. Mean Square Error (MSE) : we square the residual and then find the average of it .
# * this way the Large residual error gets more attention.
#
# ### 6. Root Mean Square Error (RMSE) : squareroot of MSE
# * this way we get the error value in the original unit
# * it tells how large your prediction errors are while heavily penalizing the large errors
#
# ### 7. R2 SCORE : (Variance mean - Variance fit) / Variance mean
# * Variance = (sum of Square of residual ) / no. of datapoints
#
# * Variance mean = only dependent variable is taken and we calculate residual wrt Mean of the dependent variable . And then average of SS.
#
# * Variance fit = the residual wrt Best Fit Line on the graph of indepedent variable v/s dependent variable . And then average of SS.
#
# * if R2 Score = 0.85 means the model explains about 80% of the variance in the target relative to the baseline mean predictor.
